# %%
# !pip install -q https://github.com/BlueBrain/MOOC-hippocampus-network-simulation-2019/raw/add-piz-daint/dynamic_analysis_pkg/dist/dynamic_analysis_pkg-0.1.7.tar.gz

# %%
import dynamic_analysis_pkg

# %%
results = dynamic_analysis_pkg.Results(oauth.get_token(), 'SIMULATION_ID', hpc_name='PIZ_DAINT')
# Out:
# Fetching results of: 5Cells - /store path
# - BlueConfig downloaded
# - 5Cells_report_0.bbp downloaded
# - out.dat downloaded

# %%
results.blueconfig
# Out:
# '/home/jovyan/tmp/test_pull_unicore/cf56b6c5-91cc-4ffc-bec8-2e6e839effe1/BlueConfig'

# %%
# !ls -l {results.local_dir}
# Out:
# total 72
# -rw-r--r-- 1 jovyan users 61464 Jul  4 12:29 5Cells_report_0.bbp
# -rw-r--r-- 1 jovyan users  1599 Jul  4 12:29 BlueConfig
# -rw-r--r-- 1 jovyan users   342 Jul  4 12:29 out.dat
